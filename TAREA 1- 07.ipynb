# %% [markdown]
# "$ Angie$ $ Gordillo$  $ y    $  $Ricardo $ $Becerra$"
#
# $$VARIABLES$$
#
#
# $ compota : $cantidad$ $ de$ $porcentaje
#
# $ Rosquillas :   $cantidad$ $ de$ $Porcentaje
#
# $ Galletas :   $cantidad$ $ de$ $Porcentaje
#
# $Arandanos :    $cantidad$ $ de$ $Porcentaje
#
# $Palitos :    $cantidad$ $ de$  $Porcentaje
#
#
# $$RESTRICCIONES$$
#
#  80 com $ + $ 140 Ros$ + $ 120Ga$ + $ 110Ara$ + $ 60 Pa$ > = 2000
#
# $  $ 45k Ros$ + $ 50Ga$ + $ 10Ara$ + $ 10 Pa$ > = 2000
#
# $  $ 0,08 Ros$ +  $ 0.99Ga$ + $ 0.02Ara$ + $ 0.02 Pa$ > = 1
#
# $  $ 0.15 Ros$ +  $ 0.15Ga$  > = 1
#
#  0.0002Com$ + $ 0.0416Ros$ > = 1
#
#  $ $ 0.14comp$ ´+ $ 1.02Ros$ + $ 0.8Ga$ +$ 1.84Ara$+ $ 0.3Pa$  >= 1
#
#  0.02 Ara > = 1
#
#  0.5comp  +  0.15 Ara    > = 1
#
#  0.09comp  > = 1
#
#  0.04 Ga +  0.0816 Pa  > = 1
#
#
#
# $$ FUNCION $$  $$  OBJETIVO $$
#
# $ $ Zmin  =  $1250com$ + $ 731.25 Ros$ +  $315Ga$ + $ 930 Ara$ +$ 252Pa $
#
#
#
#
#
#
#
#
# $...................   $     $ Compota$ | $ Rosquillas$ | $ Galletas$ | $ Arandanos$ | $ Palitos$ | $necesario$ |
#
# $  calorias $                  80      |     140       |     120     |     110      |    60      |     2000    |
#
# $ Calorias de grasa $          0       |      45       |     50      |      10      |     10     |     140-200 |
#
# $ Grasa Total  $               0       |      0.08     |     0.09    |     0.02     |    0.02    |    <=0.9    |
#
# $ Grasa saturada$              0       |      0.15     |     0.15    |     0        |     0      |     <=0.9   |
#
# $ Colesterol$                  0       |      0.02     |     0       |      0       |      0     |     <=0.9   |
#
# $ Sodio$                      0.01     |      0.13     |     0.005   |      0       |     0.04   |     <=1     |
#
# $ Carbohidrato$               0.07     |     0.06      |     0.05    |       0.08   |     0.03   |     >=1     |
#
# $ Azucares$                  13        |     1         |      9      |      19      |      0     |    25-30    |
#
# $ Proteina$                  1         |       6       |      1      |       10     |      2     |     70-90   |
#
# $ Vitamina A$                  0       |     0         |      0      |       2      |       0    |      >=1    |
#
# $ Vitamina C$                0.5       |         0     |       0     |       0.15   |      0     |     >=1     |
#
# $ Calcio$                      0.09    |      0        |       0     |     0        |        0   |    >=1      |
#
# $ Hierro$                    0         |        0      |     0.04    |      0       |       0.04 |    >=1      |
#
# $ Fibra dietaria$            0         |      0.08     |     0       |     0.08     |      0     |      >=1    |
#
#
#
# los valores fueron sacados enn proporcion al consumo diario necesario y la cantidad que suministra cada producto
#
#
# Se da en valor de porcentaje
#
# El objetivo del problema es minimizar costos
