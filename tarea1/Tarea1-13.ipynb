# %% [markdown]
# ## Carlos Villegas
# ### cod: 161003031

# %% [markdown]
# En este trabajo se busca encontrar una dieta balanceada que cumpla los requisitos nutricionales a partir de los siguientes alimentos:
#
# **- Arandanos**
#
# **- Pan de arroz**
#
# **- Palitroques**
#
# **- Compota**
#
# **- Galletas Wafer**
#
# se busca garantizar que usemos el menor costo posible.

# %% [markdown]
#    ###                        Tabla nutricional

# %% [markdown]
#    | Valor Nutricional|Palitroque|Compota|Pan de arroz|Arandanos|Waffer|Necesario|
#    |:----------------:|:--------:|:-----:|:----------:|:-------:|:-----:|:-|
#    |*Vitamina A *|0%|0%|0%|13.2%|0%|$$\geq100\%$$|
#    |*Vitamina C*|0%|50%|0%|99%|0%|$$\geq100\%$$|
#    |*Calcio*|0%|9%|26%|0%|0%|$$\geq100\%$$|
#    |*Hierro*|33.2%|0%|0%|0%|12%|$$\geq100\%$$|
#    |*Proteína*%|31.2%|0%|33.2%|13.2%|6%|$$\geq100\%$$|
#    |**Valor Comercial** | \$1800 |\$1250|\$1950|\$6200|\$1050|
#
#    Tabla 1

# %% [markdown]
# ## Cumpliendo con el valor de cada nutriente:
#
#
# #### Formula con la cual encontraremos la cantidad de paquetes necesarios para cunplir el valor en cada nutriente:
#
# $F(x) : Cantidad\ de\ paquete$
#
# $F(x)=\frac{\% minimo\ necesario}{\% por\ empaque}$
#
#
# #### En este caso no vamos a usar todos los alimentos sino los necesarios como lo son los arandanos, paqn de arroz, palitroque.
#
# .
#
# .
#
#
# **ARANDANOS:**
# El único alimento de la tabla que aporta vitamina A son los Arandanos. Para poder cumplir con: $ Vitamina A \geq100\%$
#
# $f1(x)=\frac {100}{13.2}$
#
# $f1(x)=7.57$
#
# $f1(x) \approx 8$ Empaques
#
#
# Segun la tabla 1 los 8 empaques de arandanos aportan
#
# $\bf Vitamina\ A =$ $105.6\% $
#
# $\bf Vitamina\ C =$ $792\%$
#
# $\bf Calcio =$ $0\%$
#
# $\bf Hierro =$ $0\%$
#
# $\bf Proteína =$ $105.6\%$
#
# .
#
# .
#
# **PAN DE ARROZ:** El alimento con mayor aporte de calcio de la tabla es el pan de arroz. Para poder cumplir con: $Calcio \geq100\%$
#
#
# $f2(x)=\frac {100}{26}$
#
# $f2(x)=3.84$
#
# $f2(x) \approx 4$ Empaquess
#
# Segun la tabla 2 los 4 empaques de pan de arroz aportan
#
# $\bf Calcio =$ $104\% $
#
# $\bf Vitamina\ A =$ $0\%$
#
# $\bf Vitamina\ C =$ $0\%$
#
# $\bf Hierro =$ $ 0\%$
#
# $\bf Proteína =$ $249.6\%$
#
#
# .
#
# .
#
# **PALITROQUE:** El alimento con mayor aporte de hierro de la tabla es palitroque. Para poder cumplir con: $Hierro \geq100\%$
#
#
# $f3(x)=\frac {100}{33.2}$
#
# $f3(x)=3.01$
#
# $f3(x) \approx 4$ Empaquess
#
# Segun la tabla 2 los 4 empaques de palitroque aportan
#
# $\bf Hierro =$ $132.8\% $
#
# $\bf Vitamina\ A =$ $0\%$
#
# $\bf Vitamina\ C =$ $0\%$
#
# $\bf Calcio =$ $ 0\%$
#
# $\bf Proteína =$ $132.8\%$
#
# .
#
# .
#
# ## buscando la totalidad de nutrientes : $Ft(x)= f1(x)+f2(x)+f3(x)$
#
#
#
# $\bf vitamina A total=$ $105.6\% $
#
# $\bf vitamina C total=$ $4792\% $
#
# $\bf Calcio total=$ $104\% $
#
# $\bf Hierro total=$ $132.8\% $
#
# $\bf Proteina total=$ $488\% $
#
# ## Para hallar el valor de la dieta aplicamos la siguente fotmula:
#
# $Valor\ total = \$6200*f1(x)+\$1950*f2(x)+\$1800*f3(x)$
#
# $Valor\ total= \$6200*8 + \$1950*4 +\$1800*4$
#
# $Valor\ total=  \$49600 + \$7800 +\$7200$
#
# $Valor\ total=\$64200$
