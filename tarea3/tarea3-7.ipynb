# %% [markdown]
# $ $Descripción $ $ escritura $ $ de $ $codigo $ $ de $ $ lenguaje $ $ natual $ "nltk"$
#
# $$ Ricardo Becerra - Angie Gordillo $$
#
# $ pip $  $install$  $ nltk $ -- Es para instalar el paquete nlk
#
# $import$  $nltk$ -- con esto comprobamos si la instalacion a sido satifactoria
#
# $sentence $ = """At eight o'clock on Thursday morning Arthur didn't feel very good.""" -- con esto  se crea una cadena
#
# $Comilla$  $simple$ $y$  $dobles$ : son usadas para anidar una comillas dentro de otras , al escribri comillas dobles muestra comillas simples ,  y viceversa
#
# $La$  $comilla$ $triple$  con ellas insertamos un string
#
# $Chunk$--Es la cabecera que indigas parametros para comentarios ,tamaños
#
# $averaged_perceptron_tagger$  -- es el etiquetador predeterminado a partir de la versión 3.1 de NLTK
#
# $nltk.download()$ -- descarga  nltk
#
# $tokens$ $=$  $nltk.word_tokenize(sentence)$-- llama la oracion que esta declara en sentence (esta fue declarada al comienzo del codigo)  el comando tokenize divide una cadena en subcadenas  especificas
#
# la entrada viene ciendo tokens y su salida son todas las cadenas dividas en cadenas especificas
#
# $tagged$ =$ nltk.pos_tag(tokens)$ -- colocamos etiquetas a la subdivision de cadenas
#
# $$ etiquetas $$
#
# $CC$--Conjunciones coordinadas
#
# $CD$--Número cardinal
#
# $DT$--Determinante
#
# $EX$--Clausula existencial
#
# $FW$--Extranjerismo
#
# $IN$--Preposición o Conjunciones subordinantes
#
# $JJ$-- Adjetivo
#
# $JJR$-- Adjetivo Comparativo
#
# $JJS$--Superlativo
#
# $LS$--Enumeración
#
# $MD$--Verbos modales
#
# $NN$--Sustantivo, singular o incontable
#
# $NNS$-- Sustantivo, plural
#
# $NNP$--Nombre propio, singular
#
# $NNPS$--Nombre propio, plural
#
# $PDT$--Predeterminante
#
# $POS$--Final posesivo
#
# $PRP$-- Pronombre personal
#
# $PR$$-Pronombre posesivo
#
# $RB$-Adverbio
#
# $RBR$--Adverbio comparativo
#
# $RBS$--Adverbio superlativo
#
# $RP$--Particle
#
# $SYM$--Symbol
#
# $TO$-to
#
# $UH$--Interjección
#
# $VB$--Verbo, forma base
#
# $VBD$--Verbo, tiempo pasado
#
# $VBG$--Verbo, gerundio o participio presente
#
# $VBN$--Verbo, participio pasado
#
# $VBP$--Verbo, no presente de tercera persona singular
#
# $VBZ$--Verbo, tercera persona singular presente
#
# $WDT$-- determinador de Wh
#
# $WP$-- Wh-pronombre
#
# $W$$--Pronombre de posesivo wh
#
# $WRB$-- adverbio blanco
#
# $entities$ =$ nltk.chunk.ne_chunk(tagged)$-- es el programa intérprete por excelencia de documentos en formato PS (y también PDF)
#
# $ $brew install ghostscript$ --Ghostscript   realiza la impresión de documentos en ficheros y PDF.
#
# $entities$ -- Se codica el problema de reconocimiento de entidades como un problema de etiquetado de tokens
#
# $entities.draw()$--visualiza
#
#
# $$Referencia$$
#
# 1 .) http://elclubdelautodidacta.es/wp/2011/10/python-capitulo-22-comillas-simples-dobles-y-triples/
#
#
# 2 .) https://pmoracho.github.io/blog/2017/01/04/NLTK-mi-tutorial/
#
#
# 3 .) https://www.nltk.org/api/nltk.chunk.html
#
#
# 4 .) http://jcc.dcc.fceia.unr.edu.ar/2014/slides/2014-luque.pdf
